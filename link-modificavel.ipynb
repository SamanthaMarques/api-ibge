# %%
import requests

link = "https://servicodados.ibge.gov.br/api/v3/agregados/8418/periodos/2019/variaveis/12751?localidades=N2[3]"

requisicao = requests.get(link)
informacoes = requisicao.json()

import pprint

pprint.pprint(informacoes[0]['resultados'][0]['series'])

item_busca = informacoes[0]['variavel']
resultados = informacoes[0]['resultados'][0]['series']
# Out:
# [{'localidade': {'id': '3',
#                  'nivel': {'id': 'N2', 'nome': 'Grande Região'},
#                  'nome': 'Sudeste'},
#   'serie': {'2019': '17516.14'}}]

# %%
print(item_busca)
print(resultados)
# Out:
# Área total mapeada
# [{'localidade': {'id': '3', 'nivel': {'id': 'N2', 'nome': 'Grande Região'}, 'nome': 'Sudeste'}, 'serie': {'2019': '17516.14'}}]
